# %%
pip install pandas
# Out:
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.0/10.6 MB ? eta -:--:--
#                                              0.1/10.6 MB 770.8 kB/s eta 0:00:14
#                                              0.1/10.6 MB 731.4 kB/s eta 0:00:15
#                                              0.2/10.6 MB 876.1 kB/s eta 0:00:12
#                                               0.2/10.6 MB 1.1 MB/s eta 0:00:10
#      -                                        0.3/10.6 MB 1.0 MB/s eta 0:00:11
#      -                                        0.3/10.6 MB 1.0 MB/s eta 0:00:11
#      -                                        0.4/10.6 MB 1.1 MB/s eta 0:00:10
#      -                                        0.4/10.6 MB 1.0 MB/s eta 0:00:10
#      -                                        0.5/10.6 MB 1.0 MB/s eta 0:00:10
# ...

# %%
import pandas as pd

# %%
colors = pd.Series(['Red','Blue','Green'], name = "Colors")
colors
# Out:
# 0      Red
# 1     Blue
# 2    Green
# Name: Colors, dtype: object

# %%
cars = pd.Series(['BMW','Benz','Toyota'],name = "Cars")
cars
# Out:
# 0       BMW
# 1      Benz
# 2    Toyota
# Name: Cars, dtype: object

# %%
df = pd.merge(colors,cars,right_index = True,left_index= True)
df
# Out:
#   Colors    Cars
# 0    Red     BMW
# 1   Blue    Benz
# 2  Green  Toyota

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.to_csv("exported-car-sales.csv")

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
random = pd.Series([1,2,3,4,5])
random.mean()
# Out:
# 3.0

# %%
random.sum()
#12
# Out:
# 15
